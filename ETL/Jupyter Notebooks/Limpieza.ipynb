# %%
import pandas as pd

# %%
df_amazon = pd.read_csv(r"C:\Users\patpe\Desktop\Henry\PI\PI_ML_OPS\drive-download-20230410T151040Z-001\amazon_prime_titles.csv")

# %%
df_amazon['show_id'] = 'a' + df_amazon['show_id'].astype(str)

# %%
df_disney = pd.read_csv(r"C:\Users\patpe\Desktop\Henry\PI\PI_ML_OPS\drive-download-20230410T151040Z-001\disney_plus_titles.csv")

# %%
df_disney['show_id'] = 'd' + df_disney['show_id'].astype(str)
df_disney
# Out:
#      show_id     type                                             title  \
# 0        ds1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1        ds2    Movie                            Ernest Saves Christmas
# 2        ds3    Movie                      Ice Age: A Mammoth Christmas
# 3        ds4    Movie                        The Queen Family Singalong
# 4        ds5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445  ds1446    Movie                          X-Men Origins: Wolverine
# 1446  ds1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447  ds1448    Movie                                   Eddie the Eagle
# 1448  ds1449    Movie                              Bend It Like Beckham
# 1449  ds1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# ...

# %%
df_hulu = pd.read_csv(r"C:\Users\patpe\Desktop\Henry\PI\PI_ML_OPS\drive-download-20230410T151040Z-001\hulu_titles.csv")
df_hulu
# Out:
#      show_id     type                           title director  cast  \
# 0         s1    Movie  Ricky Velez: Here's Everything      NaN   NaN
# 1         s2    Movie                    Silent Night      NaN   NaN
# 2         s3    Movie                    The Marksman      NaN   NaN
# 3         s4    Movie                            Gaia      NaN   NaN
# 4         s5    Movie                        Settlers      NaN   NaN
# ...      ...      ...                             ...      ...   ...
# 3068   s3069  TV Show  Star Trek: The Original Series      NaN   NaN
# 3069   s3070  TV Show              Star Trek: Voyager      NaN   NaN
# 3070   s3071  TV Show                       The Fades      NaN   NaN
# 3071   s3072  TV Show               The Twilight Zone      NaN   NaN
# 3072   s3073  TV Show             Tokyo Magnitude 8.0      NaN   NaN
#
#              country        date_added  release_year rating   duration  \
# ...

# %%
df_hulu['show_id'] = 'h' + df_hulu['show_id'].astype(str)
df_hulu
# Out:
#      show_id     type                           title director  cast  \
# 0        hs1    Movie  Ricky Velez: Here's Everything      NaN   NaN
# 1        hs2    Movie                    Silent Night      NaN   NaN
# 2        hs3    Movie                    The Marksman      NaN   NaN
# 3        hs4    Movie                            Gaia      NaN   NaN
# 4        hs5    Movie                        Settlers      NaN   NaN
# ...      ...      ...                             ...      ...   ...
# 3068  hs3069  TV Show  Star Trek: The Original Series      NaN   NaN
# 3069  hs3070  TV Show              Star Trek: Voyager      NaN   NaN
# 3070  hs3071  TV Show                       The Fades      NaN   NaN
# 3071  hs3072  TV Show               The Twilight Zone      NaN   NaN
# 3072  hs3073  TV Show             Tokyo Magnitude 8.0      NaN   NaN
#
#              country        date_added  release_year rating   duration  \
# ...

# %%
df_netflix = pd.read_csv(r"C:\Users\patpe\Desktop\Henry\PI\PI_ML_OPS\drive-download-20230410T151040Z-001\netflix_titles.csv")
df_netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df_netflix['show_id'] = 'n' + df_netflix['show_id'].astype(str)
df_netflix
# Out:
#      show_id     type                  title         director  \
# 0        ns1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1        ns2  TV Show          Blood & Water              NaN
# 2        ns3  TV Show              Ganglands  Julien Leclercq
# 3        ns4  TV Show  Jailbirds New Orleans              NaN
# 4        ns5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802  ns8803    Movie                 Zodiac    David Fincher
# 8803  ns8804  TV Show            Zombie Dumb              NaN
# 8804  ns8805    Movie             Zombieland  Ruben Fleischer
# 8805  ns8806    Movie                   Zoom     Peter Hewitt
# 8806  ns8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df= pd.concat([df_amazon,df_disney,df_hulu,df_netflix])

# %%
df1=df

# %%
df['rating'].fillna('G', inplace=True)

# %%
from datetime import datetime

# %%
list = df["date_added"].value_counts()

# %%
df.head(50)
# Out:
#    show_id     type                                              title  \
# 0      as1    Movie                                The Grand Seduction
# 1      as2    Movie                               Take Care Good Night
# 2      as3    Movie                               Secrets of Deception
# 3      as4    Movie                                 Pink: Staying True
# 4      as5    Movie                                      Monster Maker
# 5      as6    Movie                              Living With Dinosaurs
# 6      as7    Movie                                          Hired Gun
# 7      as8    Movie                                       Grease Live!
# 8      as9    Movie                                    Global Meltdown
# 9     as10    Movie                                     David's Mother
# 10    as11    Movie                                     Forest Fairies
# 11    as12    Movie                                          Take Care
# ...

# %%
# df_prueba = df['date_added'].str.split(' ', expand=True)
# df_prueba.head(50)

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
df
# Out:
#      show_id     type                 title         director  \
# 0        as1    Movie   The Grand Seduction     Don McKellar
# 1        as2    Movie  Take Care Good Night     Girish Joshi
# 2        as3    Movie  Secrets of Deception      Josh Webber
# 3        as4    Movie    Pink: Staying True   Sonia Anderson
# 4        as5    Movie         Monster Maker     Giles Foster
# ...      ...      ...                   ...              ...
# 8802  ns8803    Movie                Zodiac    David Fincher
# 8803  ns8804  TV Show           Zombie Dumb              NaN
# 8804  ns8805    Movie            Zombieland  Ruben Fleischer
# 8805  ns8806    Movie                  Zoom     Peter Hewitt
# 8806  ns8807    Movie                Zubaan      Mozez Singh
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# ...

# %%
df_fechas.value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\patpe\Desktop\Henry\PI\PI_ML_OPS\Limpieza.ipynb Cell 19 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/patpe/Desktop/Henry/PI/PI_ML_OPS/Limpieza.ipynb#Y101sZmlsZQ%3D%3D?line=0'>1</a> df_fechas.value_counts(dropna=False)
#
# NameError: name 'df_fechas' is not defined

# %%
# O incluso eliminarlo
# pd.options.display.max_columns = None

pd.options.display.max_rows = 3000

# %%
df['type']= df['type'].astype(str)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %%
df[['duration_int', 'duration_type.']] = df["duration"].str.split(n=1, expand=True)

# %%
df["show_id"] = df["show_id"].str.lower()
df["type"] = df["type"].str.lower()
df["title"] = df["title"].str.lower()
df["director"] = df["director"].str.lower()
df["cast"] = df["cast"].str.lower()
df["country"] = df["country"].str.lower()
df["rating"] = df["rating"].str.lower()
df["listed_in"] = df["listed_in"].str.lower()
df["description"] = df["description"].str.lower()
df["duration_type."] = df["duration_type."].str.lower()

# %%
df = df.drop(columns=["duration"])

# %%
for columna in df.columns:
    print(columna, df[columna].apply(type).unique(),df[columna].isna().sum())
# Out:
# show_id [<class 'str'>] 0
# type [<class 'str'>] 0
# title [<class 'str'>] 0
# director [<class 'str'> <class 'float'>] 8259
# cast [<class 'str'> <class 'float'>] 5321
# country [<class 'str'> <class 'float'>] 11499
# date_added [<class 'pandas._libs.tslibs.timestamps.Timestamp'>
#  <class 'pandas._libs.tslibs.nattype.NaTType'>] 9554
# release_year [<class 'int'>] 0
# rating [<class 'str'>] 0
# listed_in [<class 'str'>] 0
# description [<class 'str'> <class 'float'>] 4
# duration_int [<class 'int'>] 0
# duration_type. [<class 'str'>] 0

# %%
df
# Out:
#      show_id     type                 title         director  \
# 0        as1    movie   the grand seduction     don mckellar
# 1        as2    movie  take care good night     girish joshi
# 2        as3    movie  secrets of deception      josh webber
# 3        as4    movie    pink: staying true   sonia anderson
# 4        as5    movie         monster maker     giles foster
# ...      ...      ...                   ...              ...
# 8802  ns8803    movie                zodiac    david fincher
# 8803  ns8804  tv show           zombie dumb              NaN
# 8804  ns8805    movie            zombieland  ruben fleischer
# 8805  ns8806    movie                  zoom     peter hewitt
# 8806  ns8807    movie                zubaan      mozez singh
#
#                                                    cast         country  \
# 0        brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1      mahesh manjrekar, abhay mahajan, sachin khedekar           india
# ...

# %%
df.dtypes
# Out:
# show_id                   object
# type                      object
# title                     object
# director                  object
# cast                      object
# country                   object
# date_added        datetime64[ns]
# release_year               int64
# rating                    object
# listed_in                 object
# description               object
# duration_int               int32
# duration_type.            object
# dtype: object

# %%
df["duration_int"]=df["duration_int"].fillna(0)

# %%
df["duration_int"] = df["duration_int"].astype(int)

# %%
df["duration_type."] = df["duration_type."].astype(str)

# %%
df
# Out:
#      show_id     type                 title         director  \
# 0        as1    movie   the grand seduction     don mckellar
# 1        as2    movie  take care good night     girish joshi
# 2        as3    movie  secrets of deception      josh webber
# 3        as4    movie    pink: staying true   sonia anderson
# 4        as5    movie         monster maker     giles foster
# ...      ...      ...                   ...              ...
# 8802  ns8803    movie                zodiac    david fincher
# 8803  ns8804  tv show           zombie dumb              NaN
# 8804  ns8805    movie            zombieland  ruben fleischer
# 8805  ns8806    movie                  zoom     peter hewitt
# 8806  ns8807    movie                zubaan      mozez singh
#
#                                                    cast         country  \
# 0        brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1      mahesh manjrekar, abhay mahajan, sachin khedekar           india
# ...

# %%
df["duration_type."].replace("seasons","season",inplace=True)

# %%
df["duration_type."].value_counts()
# Out:
# min       15999
# season     6517
# nan         482
# Name: duration_type., dtype: int64

# %%
df.to_csv('base_peliculas_1.csv', index=False)
